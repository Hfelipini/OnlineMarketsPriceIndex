# %%
#Mercados Online
# Fort Delivery - https://www.deliveryfort.com.br/?&sc=3
# Angeloni - https://www.angeloni.com.br/super/
# Bistek - https://www.bistek.com.br/
# Imperatriz - https://www.supermercadosimperatriz.com.br/
# BIG - https://www.big.com.br/
# Hippo - https://www.hippo.com.br/
# Giassi - https://www.giassi.com.br/
# Koch - https://www.superkoch.com.br/
# Zoffi - https://zoffi.com.br/#/floripa
#

# %%
import requests
from bs4 import BeautifulSoup
  
def news():
    # the target we want to open    
    url='https://zoffi.com.br/#/floripa'
      
    #open with GET method
    resp=requests.get(url)
      
    #http_respone 200 means OK status
    if resp.status_code==200:
        print("Successfully opened the web page")
        print("The news are as follow :-\n")

        # we need a parser,Python built-in HTML parser is enough .
        soup=BeautifulSoup(resp.text,'html.parser')    
        print(soup)
        # l is the list which contains all the text i.e news 
        #l=soup.find("ul",{"class":"q-pa-sm nomedesc"})
      
        #now we want to print only the text part of the anchor.
        #find all the elements of a, i.e anchor
        #for i in l.findAll("q-item__label"):
        #    print(i.text)
    else:
        print("Error")
          
news()
# Out:
# Successfully opened the web page
# The news are as follow :-
#
# <!DOCTYPE html>
# ...
